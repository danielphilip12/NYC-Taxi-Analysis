# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import snowflake.connector

pd.set_option("display.max_columns", None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

USER=os.getenv("user")
PASSWORD=os.getenv("password")
ACCOUNT=os.getenv("account")
WAREHOUSE=os.getenv("warehouse")         
DATABASE=os.getenv('database')
SCHEMA=os.getenv('schema')

# %%
# conn = snowflake.connector.connect(
#     user=user,
#     password=password,
#     account=account,  
#     warehouse=warehouse,             
#     database=database,
#     schema=schema
# )

# %%
# conn.close()

# %%
def run_query(query):
    with snowflake.connector.connect(
        user=USER,
        password=PASSWORD,
        account=ACCOUNT,
        warehouse=WAREHOUSE,
        database=DATABASE,
        schema=SCHEMA
    ) as conn:
        with conn.cursor() as cursor:
            cursor.execute(query)
            return cursor.fetch_pandas_all()

# %%
# try:
#     cursor = conn.cursor()

#     cursor.execute("select * from taxi_trips")

#     df = cursor.fetch_pandas_all()

#     print(df.head())

# finally:
#     cursor.close()
#     conn.close()

# %%
head_query = """
select * from taxi_trips
limit 10
"""

head_df = run_query(head_query)

# %%
head_df.head()
# Out:
#    VENDORID  TPEP_PICKUP_DATETIME  TPEP_DROPOFF_DATETIME  PASSENGER_COUNT  \
# 0         2      1672598988000000       1672599895000000            1.000
# 1         2      1672598445000000       1672599382000000            1.000
# 2         1      1672596037000000       1672596735000000            1.000
# 3         2      1672597205000000       1672599885000000            1.000
# 4         2      1672597446000000       1672599178000000            1.000
#
#    TRIP_DISTANCE  RATECODEID STORE_AND_FWD_FLAG  PULOCATIONID  DOLOCATIONID  \
# 0          2.890       1.000                  N           137           236
# 1          9.600       1.000                  N           233           138
# 2          1.800       1.000                  N           236           151
# 3         18.840       2.000                  N           132           231
# 4          4.280       1.000                  N           230           148
#
# ...

# %%
location_key = pd.read_csv('../taxi_zone_lookup.csv')

# %%
location_key
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
# TODO: Make new view in snowflake to have the location data

# df = df\
#     .merge(location_key, how='left', left_on='PULOCATIONID', right_on='LocationID')\
#     .rename(columns={'Borough': 'PUBOROUGH', 'Zone': 'PUZONE', 'service_zone': 'PUSERVICEZONE'})\
#     .drop(columns='LocationID')\
#     .merge(location_key, how='left', left_on='DOLOCATIONID', right_on='LocationID')\
#     .rename(columns={'Borough': 'DOBOROUGH', 'Zone': 'DOZONE', 'service_zone': 'DOSERVICEZONE'})\
#     .drop(columns='LocationID')

# %% [markdown]
# ## Understanding the Dataset

# %% [markdown]
# > There are 35.7M rows in this dataset spaning across all 12 months in 2023.
# >
# > We have 31 columns of data to work with, most are from the original dataset, but others, such as pickup date, month, hour, and trip duration were created in the data cleaning/transformation steps

# %%
head_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VENDORID                10 non-null     int8
#  1   TPEP_PICKUP_DATETIME    10 non-null     int64
#  2   TPEP_DROPOFF_DATETIME   10 non-null     int64
#  3   PASSENGER_COUNT         10 non-null     float64
#  4   TRIP_DISTANCE           10 non-null     float64
#  5   RATECODEID              10 non-null     float64
#  6   STORE_AND_FWD_FLAG      10 non-null     object
#  7   PULOCATIONID            10 non-null     int16
#  8   DOLOCATIONID            10 non-null     int16
#  9   PAYMENT_TYPE            10 non-null     int8
#  10  FARE_AMOUNT             10 non-null     float64
#  11  EXTRA                   10 non-null     float64
#  12  MTA_TAX                 10 non-null     float64
#  13  TIP_AMOUNT              10 non-null     float64
# ...

# %%
# df.describe()

# %%
summary_query = \
"""
select 
    avg(fare_amount) as avg_fare,
    median(fare_amount) as median_fare,
    avg(total_amount) as avg_total,
    median(total_amount) as median_total,
    avg(trip_distance) as avg_trip_distance,
    median(trip_distance) as median_trip_distance,
    avg(passenger_count) as avg_passenger_count,
    median(passenger_count) as median_passenger_count,
    avg(trip_duration_minutes) as avg_trip_duration,
    median(trip_duration_minutes) as median_trip_duration
from taxi_trips;
"""

run_query(summary_query)
# Out:
#    AVG_FARE  MEDIAN_FARE  AVG_TOTAL  MEDIAN_TOTAL  AVG_TRIP_DISTANCE  \
# 0    19.863       13.500     29.056        21.000              3.472
#
#    MEDIAN_TRIP_DISTANCE  AVG_PASSENGER_COUNT  MEDIAN_PASSENGER_COUNT  \
# 0                 1.800                1.393                   1.000
#
#    AVG_TRIP_DURATION  MEDIAN_TRIP_DURATION
# 0             17.519                12.617

# %% [markdown]
# ### Summary Statistics
#
# | Column | Average | Median | Insights |
# | ------ | ------- | ------ | -------- |
# | Fare Amount | \$19.86 | \$13.50 | As the mean is higher than the median, there is a slight rightward skew in the data. We will confirm this with visualiations later. |
# | Total Amount | \$29.06 | \$21.00 | Same as Fare Amount, there may be a slight right skew |
# | Trip Distance (Miles) | 3.47 | 1.8 | During cleaning process, we did remove trips greater than 100 miles, as these are abnormalities. |
# | Passenger Count | 1.39 | 1 | Most trips only had one passenger |
# | Trip Duration (minutes) | 17.52 | 12.62 | This is also right skewed slightly as the mean is higher than the median |

# %% [markdown]
# ## Trip Behavior

# %%
duration_query = \
"""
select trip_duration_minutes
from taxi_trips;
"""

duration_df = run_query(duration_query)

# %%
duration_df.describe()
# Out:
#        TRIP_DURATION_MINUTES
# count           35710902.000
# mean                  17.519
# std                   42.267
# min                    0.000
# 25%                    7.650
# 50%                   12.617
# 75%                   20.617
# max                10029.183

# %%
sns.histplot(data=duration_df, x='TRIP_DURATION_MINUTES', bins=20)
# Out:
# <Axes: xlabel='TRIP_DURATION_MINUTES', ylabel='Count'>

# %% [markdown]
# We can see in the above histogram and summary statistics that there are major outliers causing the plot to become inaccurate

# %%
# sns.histplot(x=np.log(df['TRIP_DURATION_MINUTES']), bins=20)

# %% [markdown]
# Let's look at the 20 longest trips to see if we can uncover outliers missed during the original cleaning

# %%
duration_largest_query = \
"""
select 
    TRIP_DURATION_MINUTES,
    PICKUP_DATETIME,
    DROPOFF_DATETIME,
    TRIP_DISTANCE,
    FARE_AMOUNT,
    TOTAL_AMOUNT
from taxi_trips
order by TRIP_DURATION_MINUTES desc
limit 20;
"""

df_20_largest = run_query(duration_largest_query)

# %%
df_20_largest
# Out:
#     TRIP_DURATION_MINUTES     PICKUP_DATETIME    DROPOFF_DATETIME  \
# 0               10029.183 2023-01-23 11:21:51 2023-01-30 10:31:02
# 1                9987.117 2023-05-24 12:51:56 2023-05-31 11:19:03
# 2                9137.083 2023-08-16 08:19:21 2023-08-22 16:36:26
# 3                9014.900 2023-08-02 11:05:52 2023-08-08 17:20:46
# 4                7352.117 2023-08-31 08:33:05 2023-09-05 11:05:12
# 5                7348.833 2023-07-14 12:52:23 2023-07-19 15:21:13
# 6                7266.850 2023-08-16 10:56:52 2023-08-21 12:03:43
# 7                7188.317 2023-12-15 11:42:05 2023-12-20 11:30:24
# 8                7053.617 2023-02-23 14:59:05 2023-02-28 12:32:42
# 9                6764.150 2023-08-28 18:13:03 2023-09-02 10:57:12
# 10               6636.450 2023-07-14 00:29:36 2023-07-18 15:06:03
# 11               6266.383 2023-09-28 08:01:31 2023-10-02 16:27:54
# 12               6179.400 2023-01-16 10:20:33 2023-01-20 17:19:57
# ...

# %%
duration_df["TRIP_DURATION_MINUTES"].describe(
    percentiles=[.50,.75,.90,.95,.99,.999]
)
# Out:
# count   35710902.000
# mean          17.519
# std           42.267
# min            0.000
# 50%           12.617
# 75%           20.617
# 90%           32.583
# 95%           43.283
# 99%           67.967
# 99.9%        159.202
# max        10029.183
# Name: TRIP_DURATION_MINUTES, dtype: float64

# %%
p99 = duration_df["TRIP_DURATION_MINUTES"].quantile(.99)

duration_df_filtered = duration_df[
    duration_df["TRIP_DURATION_MINUTES"] <= p99
]

# %%
sns.histplot(data=duration_df_filtered, x='TRIP_DURATION_MINUTES', binwidth=3)
# Out:
# <Axes: xlabel='TRIP_DURATION_MINUTES', ylabel='Count'>

# %%
duration_df[
    (duration_df["TRIP_DURATION_MINUTES"] > 240)
].shape
# Out:
# (33065, 1)

# %%
duration_df[
    (duration_df["TRIP_DURATION_MINUTES"] > 240)
]["TRIP_DURATION_MINUTES"].describe()
# Out:
# count   33065.000
# mean     1277.951
# std       385.119
# min       240.133
# 25%      1384.617
# 50%      1419.833
# 75%      1433.033
# max     10029.183
# Name: TRIP_DURATION_MINUTES, dtype: float64

# %%
duration_df_filtered["TRIP_DURATION_MINUTES"].describe(
    percentiles=[.50,.75,.90,.95,.99,.999]
)
# Out:
# count   35353941.000
# mean          15.751
# std           11.683
# min            0.000
# 50%           12.500
# 75%           20.267
# 90%           31.350
# 95%           40.517
# 99%           57.683
# 99.9%         66.567
# max           67.967
# Name: TRIP_DURATION_MINUTES, dtype: float64

# %% [markdown]
# > There are around 33,065 rows that have trip durations over 4 hours. Looking at the 20 longest trips, many of them went on for days, but had a distance of 0 and very low fares. These are likely data entry errors and so were excluded from the visualization and analysis by limiting it to the 99th percentile ,which is just over an hour.

# %% [markdown]
# ### Key Findings
#
# - Median trip duration was 12.5 minutes.
# - 95% of trips were shorter than 40.5 minutes.
# - Several duration outliers spanning multiple days were identified.
# - These outliers were associated with zero-distance, minimum-fare trips, and durations spanning multiple days
# - A histogram of the rows up to the 99th percentile for duration was generated, and was found to be right skewed
# - The majority of trips were between 5 and 20 minutes.
# - Further investigation required before establishing a duration cleaning rule

# %% [markdown]
# ## Fare Amounts

# %%
fare_query = \
"""
select 
    fare_amount,
    total_amount,
    trip_distance,
    trip_duration_minutes,
    pickup_datetime,
    dropoff_datetime
from taxi_trips
"""

fare_df = run_query(fare_query)

# %%
total_amount_df = fare_df.copy(deep=True)

# %%
fare_df.describe()
# Out:
#        FARE_AMOUNT  TOTAL_AMOUNT  TRIP_DISTANCE  TRIP_DURATION_MINUTES  \
# count 35710902.000  35710902.000   35710902.000           35710902.000
# mean        19.863        29.056          3.472                 17.519
# min          0.000         0.000          0.000                  0.000
# 25%          9.300        15.960          1.060                  7.650
# 50%         13.500        21.000          1.800                 12.617
# 75%         21.900        30.800          3.400                 20.617
# max     386983.630    386987.630         99.920              10029.183
# std         78.104        79.420          4.556                 42.267
#
#                   PICKUP_DATETIME            DROPOFF_DATETIME
# count                    35710902                    35710902
# mean   2023-07-01 22:51:06.060987  2023-07-01 23:08:37.214272
# min           2023-01-01 00:00:05         2023-01-01 00:03:28
# 25%           2023-04-01 20:10:56         2023-04-01 20:26:42
# ...

# %% [markdown]
# we can see in the above description, the largest fare is $386,983. This doesn't make a lot of sense, so let's look at the rows with the largest fares.
#
# the median fare was \\$13.5 and the average was \$19.86

# %%
fare_df.nlargest(20, 'FARE_AMOUNT')
# Out:
#           FARE_AMOUNT  TOTAL_AMOUNT  TRIP_DISTANCE  TRIP_DURATION_MINUTES  \
# 12637045   386983.630    386987.630          1.500                 11.117
# 1995564    187502.960    187513.900         21.300                 57.000
# 19766189   143163.450    143167.450          0.700                  4.717
# 2119476     19152.900     29156.900          0.000                  0.000
# 32501587     6300.900      6304.900         40.810                274.567
# 25828633     2449.500      2451.000         12.580                302.433
# 34667472     2320.110      2372.790          6.700                 27.033
# 891264       2203.100      2208.100          0.000                  0.000
# 17384869     2194.700      2203.140         44.510               3011.383
# 10231482     1116.700      1120.700          0.000                  0.000
# 12369798     1025.000      1026.500         19.000               1411.967
# 3103968       999.000      1000.000          0.000                  1.200
# ...

# %% [markdown]
# The trip with the largest fare was only 1.5 miles and lasted only 11 minutes. this would not warrent a fare of that amount. This is also true for the other rows as well having high fares. Let's look at percentiles of the fare amount.

# %%
fare_df["FARE_AMOUNT"].describe(
    percentiles=[.50,.75,.90,.95,.99,.999]
)
# Out:
# count   35710902.000
# mean          19.863
# std           78.104
# min            0.000
# 50%           13.500
# 75%           21.900
# 90%           42.500
# 95%           70.000
# 99%           77.900
# 99.9%        150.000
# max       386983.630
# Name: FARE_AMOUNT, dtype: float64

# %% [markdown]
# The 99th percentile of the fare amounts is only $77.9. Let's see how many rows there are that are above this amount.

# %%
f99 = fare_df['FARE_AMOUNT'].quantile(.99)

# %%
high_fare_df = fare_df[fare_df['FARE_AMOUNT'] > f99]

# %%
high_fare_df.shape
# Out:
# (356816, 6)

# %% [markdown]
# There are 356.8K+ rows that have fare amounts above the 99th percentile.

# %%
filtered_fare_df = fare_df[fare_df['FARE_AMOUNT'] <= f99]

# %%
sns.histplot(data=filtered_fare_df, x='FARE_AMOUNT', bins=25)
# Out:
# <Axes: xlabel='FARE_AMOUNT', ylabel='Count'>

# %% [markdown]
# From the above histogram of the filtered fare dataframe (containing only rows below the 99th percentile), we see that most of the fares are between 5 and 20 dollars. However, there is a spike in fare amounts that are around $70.

# %% [markdown]
# ### Key Findings
# - The median fare amount is \$13.5
# - The average fare amount is \$19.86
# - The highest fare is over \$300,000
# - The extreme fare values investigated did not appear to have a justifiable relationship to trip distance or duration.
# - The 99th percentile is only ~\$77
# - Majority of fares are between \$5 and \\$20, with a spike at around \\$70
# - Further investigation required before establishing a fare amount cleaning rule

# %% [markdown]
# ## Total Amount

# %%
total_amount_df.describe()
# Out:
#        FARE_AMOUNT  TOTAL_AMOUNT  TRIP_DISTANCE  TRIP_DURATION_MINUTES  \
# count 35710902.000  35710902.000   35710902.000           35710902.000
# mean        19.863        29.056          3.472                 17.519
# min          0.000         0.000          0.000                  0.000
# 25%          9.300        15.960          1.060                  7.650
# 50%         13.500        21.000          1.800                 12.617
# 75%         21.900        30.800          3.400                 20.617
# max     386983.630    386987.630         99.920              10029.183
# std         78.104        79.420          4.556                 42.267
#
#                   PICKUP_DATETIME            DROPOFF_DATETIME
# count                    35710902                    35710902
# mean   2023-07-01 22:51:06.060987  2023-07-01 23:08:37.214272
# min           2023-01-01 00:00:05         2023-01-01 00:03:28
# 25%           2023-04-01 20:10:56         2023-04-01 20:26:42
# ...

# %% [markdown]
# we can see in the above description, the largest total amount is $386,987.63. Like with the fares, his doesn't make a lot of sense, so let's look at the rows with the largest total amounts.
#
# the median total amount was \\$21 and the average was \$26.06

# %%
total_amount_df.nlargest(20, 'TOTAL_AMOUNT')
# Out:
#           FARE_AMOUNT  TOTAL_AMOUNT  TRIP_DISTANCE  TRIP_DURATION_MINUTES  \
# 12637045   386983.630    386987.630          1.500                 11.117
# 1995564    187502.960    187513.900         21.300                 57.000
# 19766189   143163.450    143167.450          0.700                  4.717
# 2119476     19152.900     29156.900          0.000                  0.000
# 32501587     6300.900      6304.900         40.810                274.567
# 25828633     2449.500      2451.000         12.580                302.433
# 34667472     2320.110      2372.790          6.700                 27.033
# 891264       2203.100      2208.100          0.000                  0.000
# 17384869     2194.700      2203.140         44.510               3011.383
# 10231482     1116.700      1120.700          0.000                  0.000
# 12369798     1025.000      1026.500         19.000               1411.967
# 3103968       999.000      1000.000          0.000                  1.200
# ...

# %% [markdown]
# Thr trip that had the largest fare also had the highest total amount. This is true for the other rows of high fares as well, where they also had the highest total amounts. One difference is row 9,150,745, which had a total amount of \\$1,000, but a fare of only \\$14.2. this trip was only 2.3 miles and lasted 11.47 minutes, so the fare makes sense, but the total does not. Let's look a little closer that that specific row.

# %%
run_query("""
select *
from taxi_trips
where fare_amount = 14.2 and total_amount=1000
""")
# Out:
#    VENDORID  TPEP_PICKUP_DATETIME  TPEP_DROPOFF_DATETIME  PASSENGER_COUNT  \
# 0         1      1677922252000000       1677922940000000            1.000
#
#    TRIP_DISTANCE  RATECODEID STORE_AND_FWD_FLAG  PULOCATIONID  DOLOCATIONID  \
# 0          2.300       1.000                  N           226            83
#
#    PAYMENT_TYPE  FARE_AMOUNT  EXTRA  MTA_TAX  TIP_AMOUNT  TOLLS_AMOUNT  \
# 0             1       14.200  0.000    0.500     984.300         0.000
#
#    IMPROVEMENT_SURCHARGE  TOTAL_AMOUNT  CONGESTION_SURCHARGE  AIRPORT_FEE  \
# 0                  1.000      1000.000                 0.000        0.000
#
#    ABS_FARE  ABS_TOTAL  PICKUP_MONTH  PICKUP_DAY  PICKUP_HOUR  \
# 0    14.200   1000.000             3           4            9
#
#    PICKUP_DAY_OF_WEEK_NUM PICKUP_DAY_OF_WEEK PICKUP_DATE  IS_WEEKEND  \
# 0                       5           Saturday  2023-03-04        True
#
#    TRIP_DURATION_MINUTES     PICKUP_DATETIME    DROPOFF_DATETIME
# ...

# %% [markdown]
# It seems that that particular trip, while it was a small distance with a small fare, there was a large tip amount ($984.3), which explains the total amount being so high, so this is not an invalid trip.

# %%
total_amount_df["TOTAL_AMOUNT"].describe(
    percentiles=[.50,.75,.90,.95,.99,.999]
)
# Out:
# count   35710902.000
# mean          29.056
# std           79.420
# min            0.000
# 50%           21.000
# 75%           30.800
# 90%           61.550
# 95%           83.300
# 99%          104.410
# 99.9%        182.760
# max       386987.630
# Name: TOTAL_AMOUNT, dtype: float64

# %% [markdown]
# The 99th percentile is $104.41. Let's see how many rows there are with a total amount higher than this.

# %%
t99 = total_amount_df['TOTAL_AMOUNT'].quantile(0.99)

# %%
high_total_df = total_amount_df[total_amount_df['TOTAL_AMOUNT'] > t99]

# %%
high_total_df.shape
# Out:
# (350325, 6)

# %% [markdown]
# There are 350K+ rows with a total amount above the 99th percentile.

# %%
filtered_total_df = total_amount_df[total_amount_df['TOTAL_AMOUNT'] <= t99]

# %%
sns.histplot(data=filtered_total_df, x='TOTAL_AMOUNT', bins=25)
# Out:
# <Axes: xlabel='TOTAL_AMOUNT', ylabel='Count'>

# %% [markdown]
# From the above histogram, we can see that most total amounts are between 10 and 35 dollars.

# %% [markdown]
# ### Key findings
#
# - The median total amount is \$21
# - The average total amount is \$29.06
# - The highest total amount is over \$300,000
# - Outliers do not have justifiable reasons for high costs. Most have
#     - Small distances
#     - Short durations
#     - Some outliers are justified by high tips, but only a minority.
# - The 99th percentile is around \$104.41
# - Majority of fares are between \$10 and \\$35
# - Further investigation required before establishing a total amount cleaning rule

# %% [markdown]
# ## Next Session
#
# 1. Investigate Trip Distance

# %%
trip_distance_query = \
"""
select
    trip_distance,
    trip_duration_minutes,
    fare_amount,
    total_amount,
    pickup_day_of_week
from taxi_trips;
"""

# %%
trip_distance_df = run_query(trip_distance_query)
trip_distance_df.head()
# Out:
#    TRIP_DISTANCE  TRIP_DURATION_MINUTES  FARE_AMOUNT  TOTAL_AMOUNT  \
# 0          1.240                 15.583       14.200        18.200
# 1          2.240                 18.583       17.700        26.040
# 2          1.770                 12.867       13.500        21.000
# 3          1.260                 17.917       15.600        23.520
# 4          0.680                  6.083        7.200        13.440
#
#   PICKUP_DAY_OF_WEEK
# 0           Thursday
# 1           Thursday
# 2           Thursday
# 3           Thursday
# 4           Thursday

# %%
trip_distance_df['TRIP_DISTANCE'].describe(percentiles=[.50,.75,.90,.95,.99,.999])
# Out:
# count   35710902.000
# mean           3.472
# std            4.556
# min            0.000
# 50%            1.800
# 75%            3.400
# 90%            9.200
# 95%           15.630
# 99%           20.290
# 99.9%         29.840
# max           99.920
# Name: TRIP_DISTANCE, dtype: float64

# %%
trip_distance_df.nlargest(20, 'TRIP_DISTANCE')
# Out:
#           TRIP_DISTANCE  TRIP_DURATION_MINUTES  FARE_AMOUNT  TOTAL_AMOUNT  \
# 3959289          99.920                162.600      400.000       424.050
# 3623084          99.910                107.000      600.000       601.000
# 9019274          99.760                182.800      350.000       450.000
# 19461958         99.620                140.583      680.600       684.600
# 32159062         99.600                114.517      400.000       450.000
# 19941250         99.500                114.817      300.000       342.690
# 15459415         99.280                135.883      383.500       496.560
# 2621186          99.210                 94.817      224.000       225.000
# 20285167         99.190                121.950      250.000       263.050
# 21559223         99.110                161.200      325.000       327.750
# 22109756         99.100               1342.917       70.000        74.000
# 27057618         99.090                170.283      220.000       249.930
# ...

# %% [markdown]
# Looking at the 20 largest trip distances, there are some numbers that standout to me in regards to the other columns.
#
# For row 26,485,823, the trip distance was 99.1 miles and had a duration of ~1,343 minutes, or ~22 hours. However, the fare amount was only 70 dollars, and the total amount was 74 dollars. I would expect a trip that long would be hundreds of dollars, like the other rows show. Let's look more at that rows.

# %%
long_trip_small_fare_query = \
"""
select *
from taxi_trips
where trip_distance = 99.1 and trip_duration_minutes > 1342
"""

# %%
run_query(long_trip_small_fare_query)
# Out:
#    VENDORID  TPEP_PICKUP_DATETIME  TPEP_DROPOFF_DATETIME  PASSENGER_COUNT  \
# 0         2      1700687652000000       1700768227000000            2.000
#
#    TRIP_DISTANCE  RATECODEID STORE_AND_FWD_FLAG  PULOCATIONID  DOLOCATIONID  \
# 0         99.100       2.000                  N            79           216
#
#    PAYMENT_TYPE  FARE_AMOUNT  EXTRA  MTA_TAX  TIP_AMOUNT  TOLLS_AMOUNT  \
# 0             2       70.000  0.000    0.500       0.000         0.000
#
#    IMPROVEMENT_SURCHARGE  TOTAL_AMOUNT  CONGESTION_SURCHARGE  AIRPORT_FEE  \
# 0                  1.000        74.000                 2.500        0.000
#
#    ABS_FARE  ABS_TOTAL  PICKUP_MONTH  PICKUP_DAY  PICKUP_HOUR  \
# 0    70.000     74.000            11          22           21
#
#    PICKUP_DAY_OF_WEEK_NUM PICKUP_DAY_OF_WEEK PICKUP_DATE  IS_WEEKEND  \
# 0                       2          Wednesday  2023-11-22       False
#
#    TRIP_DURATION_MINUTES     PICKUP_DATETIME    DROPOFF_DATETIME
# ...

# %% [markdown]
# Looking at how long this trip is, both distance and duration wise, the fare and total amount do not make sense. To better look at the relationships, let's make a scatterplot of the trip distance vs teh fare amount.

# %%
sns.scatterplot(data=trip_distance_df, x='TRIP_DISTANCE', y='FARE_AMOUNT')
# Out:
# <Axes: xlabel='TRIP_DISTANCE', ylabel='FARE_AMOUNT'>

# %% [markdown]
# Due to some high outliers for the fare amounts, we will use the log of fare amounts to show the scatterplot.

# %%
trip_distance_df['FARE_AMOUNT_LOG'] = np.log(trip_distance_df['FARE_AMOUNT'])
# Out:
# D:\projects\NYC-Taxi-Analysis\.venv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.scatterplot(data=trip_distance_df, x='TRIP_DISTANCE', y='FARE_AMOUNT_LOG')
# Out:
# <Axes: xlabel='TRIP_DISTANCE', ylabel='FARE_AMOUNT_LOG'>

# %% [markdown]
# Looking at the above scatterplot, most of fares remain the same regardless of distance, telling us that the distance alone may not have much impact on the fare overall. We will investigate this more later after the dataset has been properly cleaned.

# %%
zero_distance_trips = trip_distance_df[trip_distance_df['TRIP_DISTANCE'] <= 0]

# %%
zero_distance_trips.shape
# Out:
# (388538, 6)

# %%
zero_distance_trips.nlargest(20, 'TOTAL_AMOUNT')
# Out:
#           TRIP_DISTANCE  TRIP_DURATION_MINUTES  FARE_AMOUNT  TOTAL_AMOUNT  \
# 19760215          0.000                  0.000    19152.900     29156.900
# 5164643           0.000                  0.000     2203.100      2208.100
# 1930759           0.000                  0.000     1116.700      1120.700
# 1341246           0.000                  3.150      999.000      1000.000
# 34282692          0.000                  1.200      999.000      1000.000
# 2621634           0.000                  0.100      995.000       996.000
# 21530649          0.000                  0.100      995.000       996.000
# 17338051          0.000                  1.367      972.000       973.000
# 14641214          0.000                  1.717      910.000       911.000
# 394287            0.000                  2.117      900.000       901.000
# 8218651           0.000                  0.200      900.000       901.000
# 26903406          0.000                  0.250      900.000       901.000
# ...

# %% [markdown]
# Looking at the trips with the 20 largest total amounts where the trip distance is 0, we can see very clearly that these trips do not make sense. Many of them have 0 distance and 0 duration (or close to 0), which is impossible to have a fare for. We should update the cleaning function to check if both the trip duration and the trip distance are 0, and remove them from the dataset, as these would be impossible trips to have accurate fares for.

# %%
distance_buckets_query = \
"""
SELECT
    FLOOR(TRIP_DISTANCE) AS DISTANCE_BUCKET,
    COUNT(*) AS TRIPS
FROM TAXI_TRIPS
GROUP BY DISTANCE_BUCKET
ORDER BY DISTANCE_BUCKET;
"""

# %%
distance_buckets = run_query(distance_buckets_query)

# %%
distance_buckets
# Out:
#     DISTANCE_BUCKET     TRIPS
# 0             0.000   7810950
# 1             1.000  11855637
# 2             2.000   5776999
# 3             3.000   2696752
# 4             4.000   1390857
# ..              ...       ...
# 95           95.000        16
# 96           96.000        13
# 97           97.000        11
# 98           98.000        10
# 99           99.000        13
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(20, 4))
sns.barplot(data=distance_buckets, x='DISTANCE_BUCKET', y='TRIPS')
plt.xticks(rotation=90);

# %%
sns.histplot(data=trip_distance_df, x='TRIP_DISTANCE', binwidth=1)
# Out:
# <Axes: xlabel='TRIP_DISTANCE', ylabel='Count'>

# %% [markdown]
# Most of the trips are between 1 and 2 miles total. We see this with both the barplot and the histogram. Very few trips go above 22 miles.

# %% [markdown]
# ## Zero Distance Trips

# %%
zero_distance_query = """
select 
    trip_distance, 
    trip_duration_minutes, 
    pickup_datetime, 
    dropoff_datetime, 
    fare_amount, 
    total_amount, 
    tip_amount, 
    pulocationid,
    dolocationid,
    payment_type,
    vendorid,
    passenger_count
from taxi_trips
where trip_distance = 0
"""

# %%
zero_dist_df = run_query(zero_distance_query)

# %%
zero_dist_df.shape
# Out:
# (388538, 12)

# %%
zero_dist_df.head()
# Out:
#    TRIP_DISTANCE  TRIP_DURATION_MINUTES     PICKUP_DATETIME  \
# 0          0.000                 61.300 2023-05-01 17:16:57
# 1          0.000                  0.017 2023-05-01 17:06:15
# 2          0.000                  0.083 2023-05-01 17:51:39
# 3          0.000                 26.267 2023-05-01 17:09:46
# 4          0.000                  0.250 2023-05-01 17:18:43
#
#      DROPOFF_DATETIME  FARE_AMOUNT  TOTAL_AMOUNT  TIP_AMOUNT  PULOCATIONID  \
# 0 2023-05-01 18:18:15       34.500        36.000       0.000           226
# 1 2023-05-01 17:06:16      105.000       116.500      10.000           264
# 2 2023-05-01 17:51:44      190.000       191.000       0.000           265
# 3 2023-05-01 17:36:02       23.700        30.250       0.000            42
# 4 2023-05-01 17:18:58        0.000         0.000       0.000           132
#
#    DOLOCATIONID  PAYMENT_TYPE  VENDORID  PASSENGER_COUNT
# 0            28             1         1            1.000
# ...

# %%
zero_dist_df.nlargest(20, 'TRIP_DURATION_MINUTES')
# Out:
#         TRIP_DISTANCE  TRIP_DURATION_MINUTES     PICKUP_DATETIME  \
# 211967          0.000              10029.183 2023-01-23 11:21:51
# 132337          0.000               9987.117 2023-05-24 12:51:56
# 82070           0.000               9137.083 2023-08-16 08:19:21
# 85142           0.000               9014.900 2023-08-02 11:05:52
# 190957          0.000               7352.117 2023-08-31 08:33:05
# 112107          0.000               7348.833 2023-07-14 12:52:23
# 372539          0.000               7266.850 2023-08-16 10:56:52
# 101579          0.000               7188.317 2023-12-15 11:42:05
# 79447           0.000               6266.383 2023-09-28 08:01:31
# 371792          0.000               5812.717 2023-08-11 10:41:02
# 329760          0.000               5796.100 2023-11-09 12:49:19
# 334279          0.000               5733.517 2023-11-09 12:13:05
# 174641          0.000               5637.717 2023-03-09 13:31:29
# ...

# %%
zero_dist_df['VENDORID'].value_counts()
# Out:
# VENDORID
# 2    239686
# 1    148852
# Name: count, dtype: int64

# %%
zero_dist_df['PAYMENT_TYPE'].value_counts()
# Out:
# PAYMENT_TYPE
# 1    250986
# 2    102842
# 3     22882
# 4     11827
# 5         1
# Name: count, dtype: int64

# %%
sns.barplot(data=zero_dist_df, x='VENDORID', y='TRIP_DURATION_MINUTES')
# Out:
# <Axes: xlabel='VENDORID', ylabel='TRIP_DURATION_MINUTES'>

# %%
zero_dist_df.groupby('VENDORID')[['TRIP_DURATION_MINUTES', 'FARE_AMOUNT', 'TOTAL_AMOUNT']].agg(['mean', 'median', 'min', 'max'])
# Out:
#          TRIP_DURATION_MINUTES                        FARE_AMOUNT         \
#                           mean median   min       max        mean median
# VENDORID
# 1                       15.639  2.117 0.000  1098.100      24.154 15.200
# 2                        8.690  0.300 0.000 10029.183      35.250 15.600
#
#                          TOTAL_AMOUNT
#            min       max         mean median   min       max
# VENDORID
# 1        0.000 19152.900       29.411 18.700 0.000 29156.900
# 2        0.000   995.000       44.374 23.500 0.000   996.000

# %%
# sns.histplot(data=zero_dist_df[zero_dist_df['TRIP_DURATION_MINUTES'] > 1], x='TRIP_DURATION_MINUTES')

# %%
duration_bins = [0, 10, 20, 30, 40, 50, 60, np.inf]
duration_labels = ["0-10", "11-20", "21-30", "31-40", "41-50", "51-60", "60+"]

# %%
zero_dist_df['duration_group'] = pd.cut(zero_dist_df['TRIP_DURATION_MINUTES'], bins=duration_bins, labels=duration_labels, include_lowest=True)

# %%
ax = sns.countplot(data=zero_dist_df, x='duration_group')
for container in ax.containers:
    ax.bar_label(container)

# %%
zero_dist_df.groupby('duration_group')['FARE_AMOUNT'].agg(['mean', 'median', 'min', 'max'])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_23832\1615903354.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   zero_dist_df.groupby('duration_group')['FARE_AMOUNT'].agg(['mean', 'median', 'min', 'max'])
#                  mean  median   min       max
# duration_group
# 0-10           32.129   8.600 0.000 19152.900
# 11-20          14.619  12.800 0.000   548.000
# 21-30          24.392  21.200 0.000   445.000
# 31-40          34.624  30.700 0.000   450.000
# 41-50          42.418  39.500 0.000   400.000
# 51-60          47.556  45.500 0.000   654.000
# 60+            52.126  51.500 0.000   600.000

# %%
z_df2 = zero_dist_df[zero_dist_df['PULOCATIONID'] == zero_dist_df['DOLOCATIONID']]

# %%
z_df2.describe()
# Out:
#        TRIP_DISTANCE  TRIP_DURATION_MINUTES             PICKUP_DATETIME  \
# count     240436.000             240436.000                      240436
# mean           0.000                  3.804  2023-07-08 23:06:06.507811
# min            0.000                  0.000         2023-01-01 00:03:08
# 25%            0.000                  0.133  2023-04-11 23:03:18.750000
# 50%            0.000                  0.267  2023-07-10 15:06:51.500000
# 75%            0.000                  0.883         2023-10-09 17:40:22
# max            0.000               9137.083         2023-12-31 23:57:46
# std            0.000                 51.334                         NaN
#
#                  DROPOFF_DATETIME  FARE_AMOUNT  TOTAL_AMOUNT  TIP_AMOUNT  \
# count                      240436   240436.000    240436.000  240436.000
# mean   2023-07-08 23:09:54.741947       33.986        42.213       4.492
# min           2023-01-01 00:03:28        0.000         0.000       0.000
# ...

# %%
z_df2.nlargest(20, 'TRIP_DURATION_MINUTES')
# Out:
#         TRIP_DISTANCE  TRIP_DURATION_MINUTES     PICKUP_DATETIME  \
# 82070           0.000               9137.083 2023-08-16 08:19:21
# 112107          0.000               7348.833 2023-07-14 12:52:23
# 79447           0.000               6266.383 2023-09-28 08:01:31
# 174641          0.000               5637.717 2023-03-09 13:31:29
# 304646          0.000               4220.317 2023-01-27 12:10:55
# 252709          0.000               4178.350 2023-10-19 14:02:28
# 268462          0.000               3933.550 2023-03-03 18:01:42
# 145358          0.000               3039.917 2023-10-20 10:26:44
# 205275          0.000               2725.283 2023-04-05 12:38:16
# 271935          0.000               2512.017 2023-03-26 15:18:05
# 258667          0.000               2510.317 2023-03-26 15:18:05
# 349065          0.000               2433.050 2023-01-11 19:07:55
# 378548          0.000               1998.100 2023-04-24 06:17:51
# ...

# %%
z_df2['TRIP_DURATION_MINUTES'].describe(percentiles=[.50,.75,.90,.95,.99,.999])
# Out:
# count   240436.000
# mean         3.804
# std         51.334
# min          0.000
# 50%          0.267
# 75%          0.883
# 90%          6.167
# 95%         14.233
# 99%         40.850
# 99.9%      286.551
# max       9137.083
# Name: TRIP_DURATION_MINUTES, dtype: float64

# %%
388538- 240436
# Out:
# 148102

# %%
z_df2.groupby('duration_group')['FARE_AMOUNT'].agg(['mean', 'median', 'min', 'max'])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_23832\1883029869.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   z_df2.groupby('duration_group')['FARE_AMOUNT'].agg(['mean', 'median', 'min', 'max'])
#                  mean  median   min     max
# duration_group
# 0-10           34.821  10.000 0.000 999.000
# 11-20          14.533  12.100 0.000 548.000
# 21-30          21.520  19.100 0.000 445.000
# 31-40          34.238  26.800 0.000 450.000
# 41-50          47.193  35.900 0.000 400.000
# 51-60          55.512  70.000 0.000 654.000
# 60+            50.832  67.200 0.000 550.000

# %%
z_df2[
    z_df2["TRIP_DURATION_MINUTES"] > 10
]["FARE_AMOUNT"].describe()
# Out:
# count   17096.000
# mean       23.074
# std        23.537
# min         0.000
# 25%        11.400
# 50%        15.600
# 75%        23.300
# max       654.000
# Name: FARE_AMOUNT, dtype: float64

# %%
(z_df2[
    z_df2["TRIP_DURATION_MINUTES"] > 10
]["FARE_AMOUNT"] <= 3
).sum()
# Out:
# np.int64(639)

# %% [markdown]
# ## Notes
#
# Rules to add
# if the trip distance is 0 and the pickup and dropoff are different locations, remove the row (impossible/improbable scenario)
#
# Rules to investigate
# if the distance is 0, duration is not 0, and pickup/dropoff are the same, remove the row (investigate further) - After further investigation, the median value for fare amounts increases as the duration increases, so there may be legitimate records where the charges accumulated, even though almost no distance was recorded.

# %% [markdown]
# Zero-distance trips were investigated for potential data-quality issues. Trips with different pickup and dropoff locations were considered inconsistent and targeted for removal. However, zero-distance trips with matching pickup and dropoff locations showed increasing median fares as trip duration increased, suggesting that some may represent legitimate meter activity. Therefore, a blanket duration-based removal rule was not applied.
