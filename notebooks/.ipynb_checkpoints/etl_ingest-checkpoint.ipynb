# %% [markdown]
# # NYC Taxi Analysis
#
# Source: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# Question: How can taxi companies position drivers to maximize ride volume?
#
# Problem: Where and when is taxi demand highest.

# %% [markdown]
# ## Initial Imports

# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

pd.set_option("display.max_columns", None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Initial Data Loading
#
# Only the first 3 months to get a feel for the data, then will make a cleaning/transforming functions to run on all the months.

# %%
df_jan = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet")
df_feb = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet")
df_mar = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet")

# %%
def display_info(df):
    print("Info")
    print("=" * 20)
    display(df.info())
    print("Describe")
    print("=" * 20)
    display(df.describe())
    print("Null Values")
    print("=" * 20)
    display(df.isna().sum())

# %%
display_info(df_jan)
# Out:
# Info
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     str
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int64(4), str(1)
# memory usage: 447.8 MB
# ...

# %%
display_info(df_feb)
# Out:
# Info
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 2913955 entries, 0 to 2913954
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     str
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), str(1)
# ...

# %%
display_info(df_mar)
# Out:
# Info
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 3403766 entries, 0 to 3403765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     str
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), str(1)
# ...

# %% [markdown]
# Looking at the above information, the 3 dataframes are mostly similar:
# - They all have the same 19 columns (with some formatting differences)
# - The same 5 columns have missing data each time
# - In those 5 columns, they all have the same amount of missing data (within their respective datasets)

# %% [markdown]
# ## Next Steps
#
# Perform following data cleaning on January 2023 to make function for remaining months.
#
# 1. Filter out data outside of the dataset's month &#x2714;
# 2. Check for patterns of missing data (Similar VendorIds, payment_types, etc.) &#x2714;
#     - Check the data dictionary for assistance
# 3. ~~Impute congestion surcharge and airport fees with 0, as null values likely mean they were not congested and/or airport trips~~
#     - Update: There are no missing values for surcharge or airport fee, as these were determined to be part of a pattern for the payment method.
# 4. Handle outliers and negative values for monetary columns (fares, fees, etc.) [ ]

# %% [markdown]
# ## Time Filtering

# %%
from pandas.tseries.offsets import MonthEnd, MonthBegin

# %%
jan_start = pd.Timestamp(
    year=2023,
    month=1,
    day=1
)
jan_start
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
jan_end = jan_start + MonthEnd(0)
jan_end
# Out:
# Timestamp('2023-01-31 00:00:00')

# %%
df_jan.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='str')

# %%
df_jan[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].describe()
# Out:
#              tpep_pickup_datetime       tpep_dropoff_datetime
# count                     3066766                     3066766
# mean   2023-01-17 00:22:26.288164  2023-01-17 00:38:06.427874
# min           2008-12-31 23:01:42         2009-01-01 14:29:11
# 25%    2023-01-09 16:21:57.250000         2023-01-09 16:37:06
# 50%    2023-01-17 08:42:29.500000  2023-01-17 08:58:30.500000
# 75%           2023-01-24 16:26:27         2023-01-24 16:42:49
# max           2023-02-01 00:56:53         2023-02-02 09:28:47

# %%
# df_jan = 
df = df_jan[(df_jan['tpep_pickup_datetime'] >= jan_start) & (df_jan['tpep_pickup_datetime'] <= jan_end) & (df_jan['tpep_dropoff_datetime'] >= jan_start)]

# %%
df.shape
# Out:
# (2966346, 19)

# %%
df_jan.shape
# Out:
# (3066766, 19)

# %%
2966346  / 3066766
# Out:
# 0.9672554084661171

# %%
df[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].describe()
# Out:
#              tpep_pickup_datetime       tpep_dropoff_datetime
# count                     2966346                     2966346
# mean   2023-01-16 12:35:55.136898  2023-01-16 12:51:34.193165
# min           2023-01-01 00:00:00         2023-01-01 00:03:28
# 25%    2023-01-09 11:36:50.500000  2023-01-09 11:51:26.250000
# 50%    2023-01-16 15:40:55.500000  2023-01-16 15:57:06.500000
# 75%    2023-01-23 19:23:53.750000         2023-01-23 19:36:25
# max           2023-01-30 23:59:58         2023-01-31 21:58:49

# %% [markdown]
# By removing the dates of pickup and dropoff that are outside of the month's first and last dates, we removed around 3% of data that would not be useful to our analysis.

# %% [markdown]
# ## Missing Data Patterns

# %%
missing_df = df[df.isna().sum(axis=1) > 0]

# %%
df.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          69382
# trip_distance                0
# RatecodeID               69382
# store_and_fwd_flag       69382
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     69382
# airport_fee              69382
# dtype: int64

# %%
missing_df.describe()
# Out:
#        VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count 69382.000                       69382                       69382
# mean      1.655  2023-01-16 07:38:20.324349  2023-01-16 07:55:02.179153
# min       1.000         2023-01-01 00:00:00         2023-01-01 00:08:00
# 25%       1.000         2023-01-09 06:33:31         2023-01-09 06:49:01
# 50%       2.000  2023-01-16 16:07:13.500000         2023-01-16 16:24:10
# 75%       2.000  2023-01-23 17:41:03.750000  2023-01-23 17:56:59.500000
# max       2.000         2023-01-30 23:59:44         2023-01-31 00:12:01
# std       0.475                         NaN                         NaN
#
#        passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# count            0.000      69382.000       0.000     69382.000     69382.000
# mean               NaN         19.253         NaN       164.592       161.287
# min                NaN          0.000         NaN         1.000         1.000
# ...

# %%
df['payment_type'].value_counts()
# Out:
# payment_type
# 1    2330961
# 2     516266
# 0      69382
# 4      32313
# 3      17424
# Name: count, dtype: int64

# %%
df['payment_type'].value_counts(normalize=True)
# Out:
# payment_type
# 1   0.786
# 2   0.174
# 0   0.023
# 4   0.011
# 3   0.006
# Name: proportion, dtype: float64

# %% [markdown]
# There is only one notable consistency for the missing values. The `payment_type` column is all 0s (Flex Fare). Looking at the value counts for payment type, there are 69382 flex fare trips. There are also the exact same amount of NA values in each of the columns that are missing data. This tells us that when a trip is a flex fare trip, there is an issue in logging the `passenger_count`, `RateCodeID`, `store_and_fwd_flag`, `congestion_surcharge`, and `airport_fee`.
#
# Flex Fare trips make up 2.3% of the data. As such, I believe it is safe to remove those rows

# %%
df = df[df['payment_type'] != 0]

# %%
df.shape[0] / df_jan.shape[0]
# Out:
# 0.9446315760641666

# %%
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# airport_fee              0
# dtype: int64

# %% [markdown]
# ## Outliers for financial columns

# %%
financial_columns = ['fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee']

# %%
df[financial_columns].describe()
# Out:
#        fare_amount       extra     mta_tax  tip_amount  tolls_amount  \
# count  2896964.000 2896964.000 2896964.000 2896964.000   2896964.000
# mean        18.325       1.563       0.488       3.359         0.524
# std         17.935       1.793       0.105       3.847         2.029
# min       -900.000      -7.500      -0.500     -96.220       -65.000
# 25%          8.600       0.000       0.500       1.000         0.000
# 50%         12.800       1.000       0.500       2.720         0.000
# 75%         19.800       2.500       0.500       4.140         0.000
# max       1160.100      12.500      53.160     380.800       196.990
#
#        improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# count            2896964.000   2896964.000           2896964.000  2896964.000
# mean                   0.982        26.984                 2.274        0.108
# std                    0.186        22.321                 0.773        0.357
# ...

# %% [markdown]
# We can see for all the financial columns, there are negative values. This could indicate an issue with the data collection, or it could just be refunded trips. Let's look at how many outliers there are for the fare amount and total amount.

# %%
df[['fare_amount', 'total_amount']].describe()
# Out:
#        fare_amount  total_amount
# count  2896964.000   2896964.000
# mean        18.325        26.984
# std         17.935        22.321
# min       -900.000      -751.000
# 25%          8.600        15.400
# 50%         12.800        20.000
# 75%         19.800        28.560
# max       1160.100      1169.400

# %% [markdown]
# We can see that there are large outliers on both the positive and negative sides. The outliers are close to the thousands or more, while 25th and 75th percentiles stay closer to 0, relatively.
#
# Let's take a look at a boxplot for both these columns.

# %%
# sns.boxplot(data=df, x='fare_amount')

# %%
# sns.boxplot(data=df, x='total_amount')

# %% [markdown]
# Looking at these boxplots, it is difficult to dicern the percentiles, but it is clear that the outliers are severely shrinking the box. Let's use scatterplots comapred with the trip distance to find anomalies.

# %%
# sns.scatterplot(data=df, x='fare_amount', y='trip_distance')

# %% [markdown]
# Hmmm... there seems to be some massive trips that are flattening the scatterplot. Let's remove those trips and see if that helps the visualization.

# %%
df['trip_distance'].describe()
# Out:
# count   2896964.000
# mean          3.445
# std          41.982
# min           0.000
# 25%           1.060
# 50%           1.790
# 75%           3.320
# max       62359.520
# Name: trip_distance, dtype: float64

# %% [markdown]
# Let's assume that trips more than 100 miles are abnormal

# %%
under_100 = (df['trip_distance'] <= 100).sum()
above_100 = (df['trip_distance'] > 100).sum()

# %%
above_100
# Out:
# np.int64(35)

# %%
under_100
# Out:
# np.int64(2896929)

# %%
df = df[df['trip_distance'] <= 100]

# %%
# sns.scatterplot(data=df, x='fare_amount', y='trip_distance')

# %% [markdown]
# This shows us something interesting, which is that most are in the positive payments, but it also shows that there are alot of trips that have high fares (or very low negative fares), but a distance of nearly 0. It also shows some very long trips for almost no fare. Let's look at this in more detail by splitting it by the payment type

# %%
# sns.relplot(data=df, x='fare_amount', y='trip_distance', col='payment_type')

# %%
# sns.relplot(data=df, x='total_amount', y='trip_distance', col='payment_type')

# %%
# df[df['payment_type'] == 3].head(30)

# %%
refunded_trips = df[df.duplicated(subset=['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance'], keep=False)].sort_index()
refunded_trips.head(30)
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 132          2  2023-01-01 00:28:29   2023-01-01 00:31:03            1.000
# 133          2  2023-01-01 00:28:29   2023-01-01 00:31:03            1.000
# 263          2  2023-01-01 00:20:18   2023-01-01 00:27:56            2.000
# 264          2  2023-01-01 00:20:18   2023-01-01 00:27:56            2.000
# 324          2  2023-01-01 00:52:22   2023-01-01 01:14:03            1.000
# 325          2  2023-01-01 00:52:22   2023-01-01 01:14:03            1.000
# 620          2  2023-01-01 00:06:39   2023-01-01 00:10:02            1.000
# 621          2  2023-01-01 00:06:39   2023-01-01 00:10:02            1.000
# 923          2  2023-01-01 00:34:39   2023-01-01 00:40:25            2.000
# 924          2  2023-01-01 00:34:39   2023-01-01 00:40:25            2.000
# 950          2  2023-01-01 00:26:51   2023-01-01 00:26:56            1.000
# ...

# %%
df['payment_type'].value_counts()
# Out:
# payment_type
# 1    2330940
# 2     516252
# 4      32313
# 3      17424
# Name: count, dtype: int64

# %% [markdown]
# Looks like the negative values refer to refunds. We see this in the payment types 3 and 4 mostly, signfied by the near mirror images in the scatter plot. Further more, when searching for duplicates by hte timestamps and sorting, it seems to alternate between positive and negative amounts, showing the trip was refunded, and so a new row was logged.
#
# We will create new columns with teh absolute values of total and fare amounts, then make a new dataframe with just those duplicate columns, and remove them from the original dataset.

# %%
df['abs_fare'] = df['fare_amount'].abs()

# %%
df['abs_total'] = df['total_amount'].abs()

# %%
df.head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36            1.000
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27            1.000
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          0.970       1.000                  N           161           141
# 1          1.100       1.000                  N            43           237
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2        9.300  1.000    0.500       0.000         0.000
# 1             1        7.900  1.000    0.500       4.000         0.000
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                  1.000        14.300                 2.500        0.000
# 1                  1.000        16.900                 2.500        0.000
#
#    abs_fare  abs_total
# 0     9.300     14.300
# 1     7.900     16.900

# %%
key_columns = [
    'tpep_pickup_datetime',
    'tpep_dropoff_datetime',
    'passenger_count',
    'trip_distance',
    'PULocationID',
    'DOLocationID',
    'abs_fare',
    'abs_total'
]

# %%
refund_candidates = df[df.duplicated(subset=key_columns, keep=False)]
refund_candidates.head(6)
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 132         2  2023-01-01 00:28:29   2023-01-01 00:31:03            1.000
# 133         2  2023-01-01 00:28:29   2023-01-01 00:31:03            1.000
# 263         2  2023-01-01 00:20:18   2023-01-01 00:27:56            2.000
# 264         2  2023-01-01 00:20:18   2023-01-01 00:27:56            2.000
# 324         2  2023-01-01 00:52:22   2023-01-01 01:14:03            1.000
# 325         2  2023-01-01 00:52:22   2023-01-01 01:14:03            1.000
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 132          0.420       1.000                  N           233           229
# 133          0.420       1.000                  N           233           229
# 263          1.190       1.000                  N           142            50
# 264          1.190       1.000                  N           142            50
# ...

# %%
df = df.drop_duplicates(subset=key_columns, keep=False)

# %% [markdown]
# We will keep the refund candidate table for further analysis later. Let's continue to clean up the original dataset, then create a function to clean any month's data as well as store that month's refund data.

# %% [markdown]
# ## Dropping Invalid Records
#
# We will see how many rows have invalid records, such as:
# - `trip_distance` < 0
# - `total_amount` < 0
# - `passenger_count` <= 0

# %%
df[df['trip_distance'] < 0]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee, abs_fare, abs_total]
# Index: []

# %%
df[df['total_amount'] < 0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3622            2  2023-01-01 00:26:35   2023-01-01 00:34:31            1.000
# 3730            2  2023-01-01 00:35:23   2023-01-01 00:35:34            1.000
# 4605            2  2023-01-01 00:04:11   2023-01-01 00:07:44            1.000
# 4609            2  2023-01-01 00:49:25   2023-01-01 00:56:05            2.000
# 7679            2  2023-01-01 01:13:55   2023-01-01 01:20:25            1.000
# ...           ...                  ...                   ...              ...
# 2895689         2  2023-01-30 23:22:48   2023-01-30 23:22:56            1.000
# 2896095         2  2023-01-30 23:38:33   2023-01-31 00:05:47            1.000
# 2896678         2  2023-01-30 23:26:02   2023-01-30 23:54:43            1.000
# 2896701         2  2023-01-30 23:29:19   2023-01-30 23:33:30            1.000
# 2896888         2  2023-01-30 23:10:12   2023-01-30 23:19:13            3.000
#
# ...

# %%
df[df['passenger_count'] <= 0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25            0.000
# 485             1  2023-01-01 00:22:18   2023-01-01 00:28:17            0.000
# 486             1  2023-01-01 00:30:59   2023-01-01 00:34:46            0.000
# 487             1  2023-01-01 00:36:19   2023-01-01 00:43:46            0.000
# 488             1  2023-01-01 00:54:23   2023-01-01 01:08:18            0.000
# ...           ...                  ...                   ...              ...
# 2896465         1  2023-01-30 23:58:13   2023-01-31 00:00:45            0.000
# 2896775         1  2023-01-30 23:38:31   2023-01-30 23:46:08            0.000
# 2896887         1  2023-01-30 23:55:00   2023-01-31 00:31:33            0.000
# 2896903         1  2023-01-30 23:18:40   2023-01-30 23:51:00            0.000
# 2896981         1  2023-01-30 23:13:34   2023-01-30 23:18:35            0.000
#
# ...

# %%
(3477 / df.shape[0]) * 100
# Out:
# 0.12178587052729395

# %%
(49518 / df.shape[0]) * 100
# Out:
# 1.734424140572488

# %% [markdown]
# There are no rows that have negative trip values, but there are trips with negative total amounts which were not classified as refunds, adn there are rows with no passenger count.
#
# However, they only make up a combined 2% of the data, so we can safely drop these rows without affecting our analysis, as these may have just been incorrectly logged records, but we have no way of knowing for sure.
#
# We will keep audit tables of them for further analysis later if required.

# %%
negative_trips = df[(df['total_amount'] < 0) | (df['fare_amount'] < 0)]
display(negative_trips.head())
negative_trips.describe()
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3622         2  2023-01-01 00:26:35   2023-01-01 00:34:31            1.000
# 3730         2  2023-01-01 00:35:23   2023-01-01 00:35:34            1.000
# 4605         2  2023-01-01 00:04:11   2023-01-01 00:07:44            1.000
# 4609         2  2023-01-01 00:49:25   2023-01-01 00:56:05            2.000
# 7679         2  2023-01-01 01:13:55   2023-01-01 01:20:25            1.000
#
#       trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 3622          1.410       1.000                  N            90
# 3730          0.010       2.000                  N            50
# 4605          0.750       1.000                  N           141
# 4609          0.600       1.000                  N           249
# 7679          1.310       1.000                  N           239
#
#       DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
zero_passenger = df[df['passenger_count'] <= 0]
display(zero_passenger.head())
zero_passenger.describe()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3           1  2023-01-01 00:03:48   2023-01-01 00:13:25            0.000
# 485         1  2023-01-01 00:22:18   2023-01-01 00:28:17            0.000
# 486         1  2023-01-01 00:30:59   2023-01-01 00:34:46            0.000
# 487         1  2023-01-01 00:36:19   2023-01-01 00:43:46            0.000
# 488         1  2023-01-01 00:54:23   2023-01-01 01:08:18            0.000
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 3            1.900       1.000                  N           138             7
# 485          1.300       1.000                  N           170           107
# 486          1.000       1.000                  N            79           107
# 487          2.300       1.000                  N           107           232
# 488          2.100       1.000                  N            79           231
#
# ...

# %%
df = df[(df['total_amount'] >= 0) & (df['fare_amount'] >= 0) & (df['passenger_count'] > 0)]

# %%
df.describe()
# Out:
#          VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count 2802015.000                     2802015                     2802015
# mean        1.741  2023-01-16 12:49:22.802829  2023-01-16 13:05:07.382481
# min         1.000         2023-01-01 00:00:05         2023-01-01 00:03:28
# 25%         1.000         2023-01-09 11:55:40  2023-01-09 12:11:18.500000
# 50%         2.000         2023-01-16 15:45:33         2023-01-16 16:01:53
# 75%         2.000         2023-01-23 19:28:44         2023-01-23 19:41:41
# max         2.000         2023-01-30 23:59:58         2023-01-31 21:58:49
# std         0.438                         NaN                         NaN
#
#        passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# count      2802015.000    2802015.000 2802015.000   2802015.000   2802015.000
# mean             1.390          3.399       1.506       166.372       164.429
# ...

# %%
df.shape
# Out:
# (2802015, 21)

# %%
df_jan.shape
# Out:
# (3066766, 19)

# %%
(1 - (df.shape[0] / df_jan.shape[0])) * 100
# Out:
# 8.63290515155053

# %% [markdown]
# In total, cleaning the data removed approximately 8.63% of the original data for the month of January. After cleaning the data, the passenger counts are 1 or more, there are no negative amounts for currency columns, the longest trip is ~97 miles (originally, it was hundreds of thousands of miles), etc.
#
# Next, we will create a function to do all this cleaning in one step that can be reused on multiple months to create clean datasets for each month, as well as audit tables for each month to investigate refunds, negative trips, and zero passenger rides.

# %% [markdown]
# ## Data Cleaning Function

# %%
def clean_data(df, month):
    # Standardize known column naming inconsistencies
    column_renames = {
        "Airport_fee": "airport_fee"
    }

    df = df.rename(columns=column_renames)
    month_start = pd.Timestamp(
        year=2023,
        month=month,
        day=1
    )

    month_end = month_start + MonthEnd(0)

    # Filter data to only have trips in the respective month
    df = df[(df['tpep_pickup_datetime'] >= month_start) & (df['tpep_pickup_datetime'] <= month_end) & (df['tpep_dropoff_datetime'] >= month_start)]

    # remove flex fare trips, as these contain missing data. 
    df = df[df['payment_type'] != 0]

    # Assume trips longer than 100 miles are abnormal. 
    df = df[df['trip_distance'] <= 100]

    # get absolute value for fare/total amounts for refund/duplicate checking
    df['abs_fare'] = df['fare_amount'].abs()
    df['abs_total'] = df['total_amount'].abs()

    key_columns = [
        'tpep_pickup_datetime',
        'tpep_dropoff_datetime',
        'passenger_count',
        'trip_distance',
        'PULocationID',
        'DOLocationID',
        'abs_fare',
        'abs_total'
    ]

    # for future reference. will be returned at end
    refund_candidates = df[df.duplicated(subset=key_columns, keep=False)]

    # remove duplicates from data to analyze
    df = df.drop_duplicates(subset=key_columns, keep=False)

    # for future analysis. trips with negative fares/totals
    negative_trips = df[(df['total_amount'] < 0) | (df['fare_amount'] < 0)]

    # for future reference, trips with 0 passengers
    zero_passenger = df[df['passenger_count'] <= 0]

    # remove negative trips and 0 passengers
    df = df[(df['total_amount'] >= 0) & (df['fare_amount'] >= 0) & (df['passenger_count'] > 0)]

    # Checks if pickup and dropoff times are reversed and switches them to be correct. 
    mask = df['tpep_pickup_datetime'] > df['tpep_dropoff_datetime']

    df.loc[mask, ['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = (
        df.loc[mask, ['tpep_dropoff_datetime', 'tpep_pickup_datetime']].to_numpy()
    )

    return (df, refund_candidates, negative_trips, zero_passenger)

# %%
df_feb.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34            2.000
# 1         2  2023-02-01 00:35:16   2023-02-01 00:35:30            1.000
# 2         2  2023-02-01 00:35:16   2023-02-01 00:35:30            1.000
# 3         1  2023-02-01 00:29:33   2023-02-01 01:01:38            0.000
# 4         2  2023-02-01 00:12:28   2023-02-01 00:25:46            1.000
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          0.300       1.000                  N           142           163
# 1          0.000       1.000                  N            71            71
# 2          0.000       1.000                  N            71            71
# 3         18.800       1.000                  N           132            26
# 4          3.220       1.000                  N           161           145
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df_feb.shape
# Out:
# (2913955, 19)

# %%
df_feb.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          76817
# trip_distance                0
# RatecodeID               76817
# store_and_fwd_flag       76817
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     76817
# Airport_fee              76817
# dtype: int64

# %%
new_df_feb, refund_feb, negative_feb, zero_feb = clean_data(df_feb, 2)

# %%
new_df_feb.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34            2.000
# 4         2  2023-02-01 00:12:28   2023-02-01 00:25:46            1.000
# 5         1  2023-02-01 00:52:40   2023-02-01 01:07:18            1.000
# 6         1  2023-02-01 00:12:39   2023-02-01 00:40:36            1.000
# 7         1  2023-02-01 00:56:53   2023-02-01 01:00:37            1.000
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          0.300       1.000                  N           142           163
# 4          3.220       1.000                  N           161           145
# 5          5.100       1.000                  N           148           236
# 6          8.900       1.000                  N           137           244
# 7          1.200       1.000                  N           263           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
new_df_feb.shape
# Out:
# (2648400, 21)

# %%
2648400 / 2913955
# Out:
# 0.9088678445617726

# %%
new_df_feb.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# airport_fee              0
# abs_fare                 0
# abs_total                0
# dtype: int64

# %%
df_jan_new = clean_data(df_jan, 1)[0]

# %%
df_jan_new.shape
# Out:
# (2802015, 21)

# %%
mask = df_jan_new['tpep_pickup_datetime'] > df_jan_new['tpep_dropoff_datetime']

df_jan_new.loc[mask, ['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = (
    df_jan_new.loc[mask, ['tpep_dropoff_datetime', 'tpep_pickup_datetime']].to_numpy()
)

# %%
(df_jan_new['tpep_pickup_datetime'] > df_jan_new['tpep_dropoff_datetime']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Old Code Below

# %%
# print(f"Total Amount under 0: {df[df['total_amount'] < 0].shape[0]}")
# print(f"Fare Amount Amount under 0: {df[df['fare_amount'] < 0].shape[0]}")

# refunded_trips.shape[0] / 2

# refunded_trips[refunded_trips['fare_amount'] < 0].shape[0]

# refunded_trips[refunded_trips['fare_amount'] >= 0].shape[0]



# pos = df[df.duplicated(subset=['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance'], keep='first')].sort_index()
# pos.head(10)

# neg = df[df.duplicated(subset=['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance'], keep='last')].sort_index()
# neg.head(10)

# pos[pos['fare_amount'] < 0]

# neg[neg['fare_amount'] > 0]

# test_row = df.loc[20539]

# df[(df['tpep_pickup_datetime'] == test_row.tpep_pickup_datetime) & (df['tpep_dropoff_datetime'] == test_row.tpep_dropoff_datetime)]
